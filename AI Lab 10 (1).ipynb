# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
df=pd.read_csv("C:/Users/DELL/Downloads/archive (3)/vehicles.csv")
df
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
df.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
df.tail()
# Out:
#                 id                                                url  \
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# 426875  wyoming  https://wyoming.craigslist.org  23590  2019.0       nissan
# 426876  wyoming  https://wyoming.craigslist.org  30590  2020.0        volvo
# 426877  wyoming  https://wyoming.craigslist.org  34990  2020.0     cadillac
# 426878  wyoming  https://wyoming.craigslist.org  28990  2018.0        lexus
# 426879  wyoming  https://wyoming.craigslist.org  30590  2019.0          bmw
#
#                            model condition    cylinders  ... size       type  \
# ...

# %%
df.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
df_encoded = df.copy()

# %%
def encodeCols(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_label_encoder = LabelEncoder()
        data_label_encoder.fit(np.ravel(data))
        df_encoded[i] = data_label_encoder.transform(df[i]) 

columns = ["url","region","region_url"]
encodeCols(columns)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  int64
#  2   region        426880 non-null  int64
#  3   region_url    426880 non-null  int64
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
def encodeCols(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_label_encoder = LabelEncoder()
        data_label_encoder.fit(np.ravel(data))
        df_encoded[i] = data_label_encoder.transform(df[i]) 

columns = ["manufacturer","model","condition"]
encodeCols(columns)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  int64
#  2   region        426880 non-null  int64
#  3   region_url    426880 non-null  int64
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  426880 non-null  int64
#  7   model         426880 non-null  int64
#  8   condition     426880 non-null  int64
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
def encodeCols(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_label_encoder = LabelEncoder()
        data_label_encoder.fit(np.ravel(data))
        df_encoded[i] = data_label_encoder.transform(df[i]) 

columns = ["cylinders","fuel","title_status"]
encodeCols(columns)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  int64
#  2   region        426880 non-null  int64
#  3   region_url    426880 non-null  int64
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  426880 non-null  int64
#  7   model         426880 non-null  int64
#  8   condition     426880 non-null  int64
#  9   cylinders     426880 non-null  int64
#  10  fuel          426880 non-null  int64
#  11  odometer      422480 non-null  float64
#  12  title_status  426880 non-null  int64
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
# def encodeCols(cols):
#     for i in cols:
#         data = pd.DataFrame({i:df[i].unique()})
#         data_label_encoder = LabelEncoder()
#         data_label_encoder.fit(np.ravel(data))
#         df_encoded[i] = data_label_encoder.transform(df[i]) 

# columns = ["city"]
# encodeCols(columns)

# %%
traindata, testdata = train_test_split(df_encoded, test_size=0.2, shuffle=False)

# %%
traindata.head(2)
# Out:
#            id     url  region  region_url  price  year  manufacturer  model  \
# 0  7222695916  301622     277         287   6000   NaN            42  29667
# 1  7218891961  121615     105         112  11900   NaN            42  29667
#
#    condition  cylinders  ...  size  type  paint_color image_url description  \
# 0          6          8  ...   NaN   NaN          NaN       NaN         NaN
# 1          6          8  ...   NaN   NaN          NaN       NaN         NaN
#
#   county state lat long posting_date
# 0    NaN    az NaN  NaN          NaN
# 1    NaN    ar NaN  NaN          NaN
#
# [2 rows x 26 columns]

# %%
testdata.head(2)
# Out:
#                 id     url  region  region_url  price    year  manufacturer  \
# 341504  7304630083  423024     399         408   9950  2000.0            13
# 341505  7304621694  423684     399         408   2995  2003.0            20
#
#         model  condition  cylinders  ...  size  type  paint_color  \
# 341504  14772          6          8  ...   NaN   NaN          NaN
# 341505  19120          6          8  ...   NaN   NaN          NaN
#
#                                                 image_url  \
# 341504  https://images.craigslist.org/00n0n_hsyhDnQrnK...
# 341505  https://images.craigslist.org/00W0W_jOPv8IatGJ...
#
#                                               description county state  \
# 341504  Nice local 1 owner from new. Clean Car Fax - N...    NaN    pa
# 341505  Up for sale 2003 JEEP LIBERTY 4 x 4, 3.7L, aut...    NaN    pa
#
#               lat       long              posting_date
# 341504  39.960988 -77.073482  2021-04-10T09:49:49-0400
# ...

# %%
train_x = traindata.iloc[:, 1:]
train_x.head()
# Out:
#       url  region  region_url  price  year  manufacturer  model  condition  \
# 0  301622     277         287   6000   NaN            42  29667          6
# 1  121615     105         112  11900   NaN            42  29667          6
# 2  183300     111         173  21000   NaN            42  29667          6
# 3  420567     396         404   1500   NaN            42  29667          6
# 4  147454     131         136   4900   NaN            42  29667          6
#
#    cylinders  fuel  ...  size  type paint_color image_url description county  \
# 0          8     5  ...   NaN   NaN         NaN       NaN         NaN    NaN
# 1          8     5  ...   NaN   NaN         NaN       NaN         NaN    NaN
# 2          8     5  ...   NaN   NaN         NaN       NaN         NaN    NaN
# 3          8     5  ...   NaN   NaN         NaN       NaN         NaN    NaN
# 4          8     5  ...   NaN   NaN         NaN       NaN         NaN    NaN
#
#   state lat long posting_date
# ...

# %%
train_y = traindata.iloc[:, 0]
train_y.head()
# Out:
# 0    7222695916
# 1    7218891961
# 2    7221797935
# 3    7222270760
# 4    7210384030
# Name: id, dtype: int64

# %%
test_x = testdata.iloc[:, 1:]
test_x.head()
# Out:
#            url  region  region_url  price    year  manufacturer  model  \
# 341504  423024     399         408   9950  2000.0            13  14772
# 341505  423684     399         408   2995  2003.0            20  19120
# 341506  423575     399         408  36590  2019.0             7   9772
# 341507  423602     399         408  38990  2019.0            39  27859
# 341508  423362     399         408   6200  2009.0            16  10633
#
#         condition  cylinders  fuel  ...  size       type paint_color  \
# 341504          6          8     2  ...   NaN        NaN         NaN
# 341505          6          8     2  ...   NaN        NaN         NaN
# 341506          2          6     2  ...   NaN      coupe         red
# 341507          2          6     2  ...   NaN     pickup      silver
# 341508          2          3     2  ...   NaN  hatchback       black
#
#                                                 image_url  \
# 341504  https://images.craigslist.org/00n0n_hsyhDnQrnK...
# ...

# %%
test_y = testdata.iloc[:, 0]
test_y.head()
# Out:
# 341504    7304630083
# 341505    7304621694
# 341506    7304611726
# 341507    7304611748
# 341508    7304404068
# Name: id, dtype: int64
